# %%
import pandas as pd
from datetime import date

# %%
Jan_19 = pd.read_csv("../data/201901-citibike-tripdata.csv")
Feb_19 = pd.read_csv("../data/201902-citibike-tripdata.csv") 
Mar_19 = pd.read_csv("../data/201903-citibike-tripdata.csv") 
Apr_19 = pd.read_csv("../data/201904-citibike-tripdata.csv") 
May_19 = pd.read_csv("../data/201905-citibike-tripdata.csv") 
Jun_19 = pd.read_csv("../data/201906-citibike-tripdata.csv") 
Jul_19 = pd.read_csv("../data/201907-citibike-tripdata.csv") 
Aug_19 = pd.read_csv("../data/201908-citibike-tripdata.csv") 
Sep_19 = pd.read_csv("../data/201909-citibike-tripdata.csv") 
Oct_19 = pd.read_csv("../data/201910-citibike-tripdata.csv") 
Nov_19 = pd.read_csv("../data/201911-citibike-tripdata.csv") 
Dec_19 = pd.read_csv("../data/201912-citibike-tripdata.csv")

# %%
Year_Agg = pd.concat([Jan_19, Feb_19, Mar_19, Apr_19, May_19, Jun_19, Jul_19, Aug_19, Sep_19, Oct_19, Nov_19, Dec_19], ignore_index = True)
Year_Agg = Year_Agg.loc[Year_Agg['tripduration']]
Year_Agg
# Out:
#       tripduration                 starttime                  stoptime  \
# 320           1109  2019-01-01 01:44:46.7100  2019-01-01 02:03:16.4670
# 316            142  2019-01-01 01:44:30.8630  2019-01-01 01:46:52.9140
# 591            618  2019-01-01 02:36:06.0650  2019-01-01 02:46:24.0660
# 2719           194  2019-01-01 10:27:33.4060  2019-01-01 10:30:47.7060
# 303            779  2019-01-01 01:42:08.3060  2019-01-01 01:55:07.5220
# ...            ...                       ...                       ...
# 93             468  2019-01-01 00:49:05.1410  2019-01-01 00:56:53.2090
# 786            547  2019-01-01 03:30:53.5110  2019-01-01 03:40:00.8180
# 351            788  2019-01-01 01:50:31.2160  2019-01-01 02:03:39.6790
# 1571           315  2019-01-01 08:26:58.8220  2019-01-01 08:32:14.7880
# 310            180  2019-01-01 01:43:35.6470  2019-01-01 01:46:35.7700
#
#       start station id        start station name  start station latitude  \
# ...

# %%
Year_Agg['Age'] = date.today().year - Year_Agg['birth year']
Year_Agg
# Out:
#       tripduration                 starttime                  stoptime  \
# 320           1109  2019-01-01 01:44:46.7100  2019-01-01 02:03:16.4670
# 316            142  2019-01-01 01:44:30.8630  2019-01-01 01:46:52.9140
# 591            618  2019-01-01 02:36:06.0650  2019-01-01 02:46:24.0660
# 2719           194  2019-01-01 10:27:33.4060  2019-01-01 10:30:47.7060
# 303            779  2019-01-01 01:42:08.3060  2019-01-01 01:55:07.5220
# ...            ...                       ...                       ...
# 93             468  2019-01-01 00:49:05.1410  2019-01-01 00:56:53.2090
# 786            547  2019-01-01 03:30:53.5110  2019-01-01 03:40:00.8180
# 351            788  2019-01-01 01:50:31.2160  2019-01-01 02:03:39.6790
# 1571           315  2019-01-01 08:26:58.8220  2019-01-01 08:32:14.7880
# 310            180  2019-01-01 01:43:35.6470  2019-01-01 01:46:35.7700
#
#       start station id        start station name  start station latitude  \
# ...

# %%
youngest = min(Year_Agg['Age'])
oldest = max(Year_Agg['Age'])
bin_list = [youngest, 25, 35, 45, 55, 65, oldest]
my_group_names = ["17-24","25-34","35-44","45-54","55-64","65+"]
Year_Agg["Age Group"] = pd.cut(Year_Agg["Age"],bin_list, labels = my_group_names, include_lowest = True)
Year_Agg
# Out:
#       tripduration                 starttime                  stoptime  \
# 320           1109  2019-01-01 01:44:46.7100  2019-01-01 02:03:16.4670
# 316            142  2019-01-01 01:44:30.8630  2019-01-01 01:46:52.9140
# 591            618  2019-01-01 02:36:06.0650  2019-01-01 02:46:24.0660
# 2719           194  2019-01-01 10:27:33.4060  2019-01-01 10:30:47.7060
# 303            779  2019-01-01 01:42:08.3060  2019-01-01 01:55:07.5220
# ...            ...                       ...                       ...
# 93             468  2019-01-01 00:49:05.1410  2019-01-01 00:56:53.2090
# 786            547  2019-01-01 03:30:53.5110  2019-01-01 03:40:00.8180
# 351            788  2019-01-01 01:50:31.2160  2019-01-01 02:03:39.6790
# 1571           315  2019-01-01 08:26:58.8220  2019-01-01 08:32:14.7880
# 310            180  2019-01-01 01:43:35.6470  2019-01-01 01:46:35.7700
#
#       start station id        start station name  start station latitude  \
# ...

# %%
DemographicTable = Year_Agg.groupby(["usertype", "gender","Age Group"])["tripduration"].describe()
DemographicTable
# Out:
#                                  count         mean          std     min  \
# usertype   gender Age Group
# Customer   0      17-24            6.0  2494.500000   364.249228  1772.0
#                   25-34          153.0   747.183007   646.655469   216.0
#                   35-44            5.0  1380.600000   597.607145   716.0
#                   45-54       816113.0  1499.741626  2914.252754    62.0
#            1      17-24       198472.0  1362.247410  6259.797183    65.0
#                   25-34       320263.0  3268.179702  7347.392507    96.0
#                   35-44       188018.0   933.997548   567.810406    64.0
#                   45-54        32096.0   767.666937  1311.033090   143.0
#                   55-64         1548.0  1506.681525  2267.815726   140.0
#                   65+              5.0  2628.800000  1053.635231   744.0
#            2      17-24        80991.0   960.018261  6026.933732   131.0
# ...

# %%
#Year_Agg_Subset = Year_Agg.sample(10)
#Year_Agg_Subset[["Age Group","tripduration"]].boxplot(by=["Age Group"],figsize=(12,12))

# %%
Year_Agg.set_index(["usertype", "gender","Age Group"],inplace=True)
Year_Agg

# %%
Filtering_Table = pd.merge(Year_Agg,DemographicTable,left_index=True,right_index=True)

# %%
Filtering_Table
